# %%
# negtive or positive
num = -10
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else :
    print("zero")
# Out:
# Negative

# %%
# Even or odd

num = 55
if num % 2 == 0:
    print('even')
else:
    print("odd")
# Out:
# odd

# %%
# divisble by 5
num = 1
if num % 5 == 0:
    print("divisble by 5")
else:
    print('not divisble by 5')
# Out:
# not divisble by 5

# %%
# divisble by 5 and 3
num = 6
if num % 3 == 0 and num % 5 == 0:
    print("num is divisble by 3 and 5")
else:
    print("not divisble")
# Out:
# not divisble
